# %% [markdown]
# # Predicting House Prices

# %%
# The data is available on AWS S3 at https://ddc-datascience.s3.amazonaws.com/Projects/Project.2-Housing/Data/Housing.Data.csv

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

# %%
base_data = "https://ddc-datascience.s3.amazonaws.com/Projects/Project.2-Housing/Data/Housing.Data.csv"

# %%
housing_p = pd.read_csv(base_data)
housing_p
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0     905101070           20        RL          62.0     14299   Pave   NaN
# 1     905101330           90        RL          72.0     10791   Pave   NaN
# 2     903454090           50        RM          50.0      9000   Pave   NaN
# 3     533244030           60        FV          68.0      7379   Pave   NaN
# 4     909252020           70        RL          60.0      7200   Pave   NaN
# ...         ...          ...       ...           ...       ...    ...   ...
# 2632  903231070           50        RM          52.0      6240   Pave   NaN
# 2633  906201021           80        RL          74.0     10778   Pave   NaN
# 2634  533253070          120        RL          61.0      3782   Pave   NaN
# 2635  527376100           20        RL          78.0     10140   Pave   NaN
# 2636  528292060           60        RL          41.0     12460   Pave   NaN
#
# ...

# %% [markdown]
# ## exploratory data analysis

# %%
housing_p.tail(10)
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 2627  907135040           20        RL         112.0     10859   Pave   NaN
# 2628  907280040           60        RL          75.0      9375   Pave   NaN
# 2629  909252170           70        RL          53.0      6720   Pave   NaN
# 2630  534401130           80        RL          82.0      9020   Pave   NaN
# 2631  535457020           20        RL          80.0      8000   Pave   NaN
# 2632  903231070           50        RM          52.0      6240   Pave   NaN
# 2633  906201021           80        RL          74.0     10778   Pave   NaN
# 2634  533253070          120        RL          61.0      3782   Pave   NaN
# 2635  527376100           20        RL          78.0     10140   Pave   NaN
# 2636  528292060           60        RL          41.0     12460   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence  \
# ...

# %%
housing_p.sort_values(by ="SalePrice")
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 37    902207130           30        RM          68.0      9656   Pave   NaN
# 372   910251050           20   A (agr)          80.0     14584   Pave   NaN
# 602   902477120           30   C (all)          60.0      7879   Pave   NaN
# 29    909101330           30        RL          60.0      8088   Pave  Grvl
# 1593  911175430           20   C (all)          50.0      9000   Pave   NaN
# ...         ...          ...       ...           ...       ...    ...   ...
# 323   528110020           20        RL         105.0     13693   Pave   NaN
# 2163  528150070           20        RL         100.0     12919   Pave   NaN
# 1868  528164060           20        RL         106.0     12720   Pave   NaN
# 2546  528320060           60        RL         118.0     35760   Pave   NaN
# 2494  528320050           60        RL         160.0     15623   Pave   NaN
#
# ...

# %%
with pd.option_context('display.max_columns', 82):
    display(housing_p.head())
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  905101070           20        RL          62.0     14299   Pave   NaN
# 1  905101330           90        RL          72.0     10791   Pave   NaN
# 2  903454090           50        RM          50.0      9000   Pave   NaN
# 3  533244030           60        FV          68.0      7379   Pave   NaN
# 4  909252020           70        RL          60.0      7200   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       Reg          Lvl    AllPub     Inside        Gtl       Sawyer
# 1       Reg          Lvl    AllPub     Inside        Gtl       Sawyer
# 2       Reg          Bnk    AllPub     Inside        Gtl       IDOTRR
# 3       IR1          Lvl    AllPub     Inside        Gtl      Somerst
# 4       Reg          Lvl    AllPub     Inside        Gtl        SWISU
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# ...

# %%
housing_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2637 entries, 0 to 2636
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PID              2637 non-null   int64
#  1   MS SubClass      2637 non-null   int64
#  2   MS Zoning        2637 non-null   object
#  3   Lot Frontage     2188 non-null   float64
#  4   Lot Area         2637 non-null   int64
#  5   Street           2637 non-null   object
#  6   Alley            180 non-null    object
#  7   Lot Shape        2637 non-null   object
#  8   Land Contour     2637 non-null   object
#  9   Utilities        2637 non-null   object
#  10  Lot Config       2637 non-null   object
#  11  Land Slope       2637 non-null   object
#  12  Neighborhood     2637 non-null   object
#  13  Condition 1      2637 non-null   object
#  14  Condition 2      2637 non-null   object
#  15  Bldg Type        2637 non-null   object
# ...

# %%
housing_p.dtypes.value_counts()
# Out:
# object     43
# int64      27
# float64    11
# Name: count, dtype: int64

# %%
nunique = housing_p.nunique().sort_values( ascending = False )
nunique
# Out:
# PID               2637
# Lot Area          1799
# Gr Liv Area       1216
# Bsmt Unf SF       1080
# 1st Flr SF        1022
#                   ...
# Bsmt Half Bath       3
# Paved Drive          3
# Street               2
# Alley                2
# Central Air          2
# Length: 81, dtype: int64

# %%
pd.set_option('display.max_rows', 10)

# %%
housing_p.select_dtypes(include = ["int64"])
# Out:
#             PID  MS SubClass  Lot Area  Overall Qual  Overall Cond  \
# 0     905101070           20     14299             4             3
# 1     905101330           90     10791             4             5
# 2     903454090           50      9000             6             6
# 3     533244030           60      7379             8             5
# 4     909252020           70      7200             7             9
# ...         ...          ...       ...           ...           ...
# 2632  903231070           50      6240             6             6
# 2633  906201021           80     10778             7             6
# 2634  533253070          120      3782             8             5
# 2635  527376100           20     10140             6             5
# 2636  528292060           60     12460             7             5
#
#       Year Built  Year Remod/Add  1st Flr SF  2nd Flr SF  Low Qual Fin SF  \
# 0           1964            1964        1005           0                0
# ...

# %%
housing_p.describe()
# Out:
#                 PID  MS SubClass  Lot Frontage       Lot Area  Overall Qual  \
# count  2.637000e+03  2637.000000   2188.000000    2637.000000   2637.000000
# mean   7.141301e+08    57.349261     69.166819   10044.694729      6.097459
# std    1.887527e+08    42.499091     23.356779    6742.549521      1.411522
# min    5.263011e+08    20.000000     21.000000    1300.000000      1.000000
# 25%    5.284770e+08    20.000000     58.000000    7436.000000      5.000000
# 50%    5.354530e+08    50.000000     68.000000    9450.000000      6.000000
# 75%    9.071870e+08    70.000000     80.000000   11526.000000      7.000000
# max    1.007100e+09   190.000000    313.000000  164660.000000     10.000000
#
#        Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  \
# count   2637.000000  2637.000000     2637.000000   2614.000000   2636.000000
# mean       5.569966  1971.288586     1984.202882    101.887911    438.441199
# ...

# %%
housing_p.isnull().sum().sort_values( ascending = False )
# Out:
# Pool QC           2626
# Misc Feature      2541
# Alley             2457
# Fence             2109
# Mas Vnr Type      1607
#                   ...
# Mo Sold              0
# Yr Sold              0
# Sale Type            0
# Sale Condition       0
# SalePrice            0
# Length: 81, dtype: int64

# %%
housing_p_lr = housing_p[['SalePrice', 'Lot Area']]
housing_p_lr
# Out:
#       SalePrice  Lot Area
# 0        115400     14299
# 1         90000     10791
# 2        141000      9000
# 3        254000      7379
# 4        155000      7200
# ...         ...       ...
# 2632     114500      6240
# 2633     162000     10778
# 2634     211500      3782
# 2635     165000     10140
# 2636     225000     12460
#
# [2637 rows x 2 columns]

# %%
# the items have no significance in the price many cells are empty
housing_p_fence = housing_p[['SalePrice', 'Fence', 'Misc Feature', 'Alley', 'Pool QC']]
housing_p_fence.head(10).sort_values( 'SalePrice', ascending = False )
# Out:
#    SalePrice  Fence Misc Feature Alley Pool QC
# 3     254000    NaN          NaN   NaN     NaN
# 8     235000    NaN          NaN   NaN     NaN
# 6     194500    NaN          NaN   NaN     NaN
# 7     185000    NaN          NaN   NaN     NaN
# 4     155000  MnPrv          NaN   NaN     NaN
# 9     152000    NaN          NaN  Pave     NaN
# 2     141000    NaN          NaN   NaN     NaN
# 5     125000  MnPrv          NaN   NaN     NaN
# 0     115400  MnPrv          NaN   NaN     NaN
# 1      90000    NaN         Shed   NaN     NaN

# %%
drop_ids = nunique[ nunique == housing_p.shape[0] ].index
drop_ids
# Out:
# Index(['PID'], dtype='object')

# %% [markdown]
# ## Cleaning

# %%
housing_p_c = housing_p.copy()

# %%
# getting rid of the rows that are more the 80% null
housing_p_c.drop(columns = ["PID", 'Fence', 'Misc Feature', 'Alley', 'Pool QC'],inplace = True)

# %%
#dropped row from 81 to 75
housing_p_c.shape
# Out:
# (2637, 76)

# %%
housing_p_c.isnull().sum().sort_values( ascending = False ).head(10)
# Out:
# Mas Vnr Type      1607
# Fireplace Qu      1284
# Lot Frontage       449
# Garage Yr Blt      147
# Garage Finish      147
# Garage Qual        147
# Garage Cond        147
# Garage Type        145
# Bsmt Exposure       76
# BsmtFin Type 2      74
# dtype: int64

# %%
housing_p_c.sort_values( by = ['SalePrice'] , ascending = False)
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Lot Shape  \
# 2494           60        RL         160.0     15623   Pave       IR1
# 2546           60        RL         118.0     35760   Pave       IR1
# 1868           20        RL         106.0     12720   Pave       Reg
# 2163           20        RL         100.0     12919   Pave       IR1
# 323            20        RL         105.0     13693   Pave       Reg
# ...           ...       ...           ...       ...    ...       ...
# 1593           20   C (all)          50.0      9000   Pave       Reg
# 29             30        RL          60.0      8088   Pave       Reg
# 602            30   C (all)          60.0      7879   Pave       Reg
# 372            20   A (agr)          80.0     14584   Pave       Reg
# 37             30        RM          68.0      9656   Pave       Reg
#
#      Land Contour Utilities Lot Config Land Slope  ... Enclosed Porch  \
# ...

# %%
housing_p_c.shape
# Out:
# (2637, 76)

# %%
#have to turn all strings to int64 so better understand info

# %%
housing_p_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2637 entries, 0 to 2636
# Data columns (total 76 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MS SubClass      2637 non-null   int64
#  1   MS Zoning        2637 non-null   object
#  2   Lot Frontage     2188 non-null   float64
#  3   Lot Area         2637 non-null   int64
#  4   Street           2637 non-null   object
#  5   Lot Shape        2637 non-null   object
#  6   Land Contour     2637 non-null   object
#  7   Utilities        2637 non-null   object
#  8   Lot Config       2637 non-null   object
#  9   Land Slope       2637 non-null   object
#  10  Neighborhood     2637 non-null   object
#  11  Condition 1      2637 non-null   object
#  12  Condition 2      2637 non-null   object
#  13  Bldg Type        2637 non-null   object
#  14  House Style      2637 non-null   object
#  15  Overall Qual     2637 non-null   int64
# ...

# %%
fig, axs = plt.subplots(3,25, figsize = (20,8)) # Creating 2x4 subplots because we have 8 columns in our data
column_names = housing_p_c.columns
n = 0
for i in range(3): # Loop through rows
  for j in range(25): # Loop through columns
    axs[i,j].hist(housing_p_c[column_names[n]])
    axs[i,j].set_xlabel(column_names[n])
    axs[i,j].set_ylabel('SalePrice')
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_26668/4042356341.py in <cell line: 0>()
#       4 for i in range(3): # Loop through rows
#       5   for j in range(25): # Loop through columns
# ----> 6     axs[i,j].hist(housing_p_c[column_names[n]])
#       7     axs[i,j].set_xlabel(column_names[n])
#       8     axs[i,j].set_ylabel('SalePrice')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
nm #corr_matrix = housing_p.corr()
#corr

# %%
#once correclation matrix heat map done. move forward to the linear regression graph
# 2. Seperate feutures x = housing_p_lr.drop(['SalesPrice'])
# X_train, X_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 42) fill this up

# %%
#play around with different ways to make since of the data
#try the QQ plot

# %%
#figure out the outliars
