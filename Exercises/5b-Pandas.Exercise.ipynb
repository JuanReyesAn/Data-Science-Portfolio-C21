# %% [markdown]
# # Python Exercises - Pandas

# %% [markdown]
# ## Problem 1

# %% [markdown]
# Imagine three people, e.g. family, friends, cohort.
#
# Create a pandas data frame called `cities_df` that contains the following columns:
#
# * Cities - At least 5 cities in the US
# * States - The states that those cities reside in
# * Region - The region that those cities reside in (NW, SW, Midwest, etc.)
# * Times_1 - The number of times person 1 has been to each city
# * Times_2 - The number of times person 2 has been to each city
# * Times_3 - The number of times person 3 has been to each city

# %%
import pandas as pd
import numpy as np

# %%
#Assignment = {
 #   "cities": ["Albuquerque Miami Houston Chicago Santa Fe".split()],
 #   "states": ["New Mexico Florida Texas Illinois New Mexico".split()],
 #   "Region": ["Midwest SW Midwest NW Midwest".split()],
 #   "Times_1": ["10 0 5 3 11".split()],
 #   "Times_2": ["2 8 0 25 15".split()],
 #   "Times_3": ["12 18 4 1 17".split()],
#}
#cities_df = pd.DataFrame(Assignment)
#cities_df

# %%
Assignment = {
    "cities": ["Albuquerque", "Miami", "Houston", "Chicago", "Santa Fe"],
    "states": ["New Mexico", "Florida", "Texas", "Illinois", "New Mexico"],
    "region": ["Midwest", "SW", "Midwest", "NW", "Midwest", ],
    "Times_1": [10, 0, 5, 3, 11],
    "Times_2": [2, 8, 0, 25, 15],
    "Times_3": [12, 18, 4, 1, 17],
}
cities_df = pd.DataFrame(Assignment)
cities_df
# Out:
#         cities      states   region  Times_1  Times_2  Times_3
# 0  Albuquerque  New Mexico  Midwest       10        2       12
# 1        Miami     Florida       SW        0        8       18
# 2      Houston       Texas  Midwest        5        0        4
# 3      Chicago    Illinois       NW        3       25        1
# 4     Santa Fe  New Mexico  Midwest       11       15       17

# %% [markdown]
# ## Problem 2

# %% [markdown]
# Use the `.describe()` and `.info()` methods on your data frame

# %%
cities_df.describe()
# Out:
#          Times_1    Times_2    Times_3
# count   5.000000   5.000000   5.000000
# mean    5.800000  10.000000  10.400000
# std     4.658326  10.222524   7.635444
# min     0.000000   0.000000   1.000000
# 25%     3.000000   2.000000   4.000000
# 50%     5.000000   8.000000  12.000000
# 75%    10.000000  15.000000  17.000000
# max    11.000000  25.000000  18.000000

# %%
pd.DataFrame(cities_df).index[2]
# Out:
# 2

# %% [markdown]
# ## Problem 3

# %% [markdown]
# Use indexing to access the Cities column

# %%
pd.DataFrame(cities_df)
# Out:
#         cities      states   region  Times_1  Times_2  Times_3
# 0  Albuquerque  New Mexico  Midwest       10        2       12
# 1        Miami     Florida       SW        0        8       18
# 2      Houston       Texas  Midwest        5        0        4
# 3      Chicago    Illinois       NW        3       25        1
# 4     Santa Fe  New Mexico  Midwest       11       15       17

# %%
cities_df["cities"]
# Out:
# 0    Albuquerque
# 1          Miami
# 2        Houston
# 3        Chicago
# 4       Santa Fe
# Name: cities, dtype: object

# %%
# or do this
cities_df.iloc[1]
# Out:
# cities       Miami
# states     Florida
# region          SW
# Times_1          0
# Times_2          8
# Times_3         18
# Name: 1, dtype: object

# %% [markdown]
# ## Problem 4

# %% [markdown]
# Create a new column called `Total_Times` that contains the total number of times all team members have been to each city.

# %%
cities_df
# Out:
#         cities      states   region  Times_1  Times_2  Times_3
# 0  Albuquerque  New Mexico  Midwest       10        2       12
# 1        Miami     Florida       SW        0        8       18
# 2      Houston       Texas  Midwest        5        0        4
# 3      Chicago    Illinois       NW        3       25        1
# 4     Santa Fe  New Mexico  Midwest       11       15       17

# %%
#cities_df["Total_Times"] = np.DataFrame[24, 26, 9, 29, 43]
#cities_df

# %%
cities_df["Total_Times"] = cities_df["Times_1"] + cities_df["Times_2"] + cities_df["Times_3"]
pd.DataFrame(cities_df)
# Out:
#         cities      states   region  Times_1  Times_2  Times_3  Total_Times
# 0  Albuquerque  New Mexico  Midwest       10        2       12           24
# 1        Miami     Florida       SW        0        8       18           26
# 2      Houston       Texas  Midwest        5        0        4            9
# 3      Chicago    Illinois       NW        3       25        1           29
# 4     Santa Fe  New Mexico  Midwest       11       15       17           43

# %%
cities_df["Times_1"] + cities_df["Times_2"] + cities_df["Times_3"]
# Out:
# 0    24
# 1    26
# 2     9
# 3    29
# 4    43
# dtype: int64

# %% [markdown]
# ## Problem 5

# %% [markdown]
# Use indexing to access the cities that have been travelled to more than two times.

# %%
cities_df.loc[cities_df["Total_Times"] > 2, ["cities"]]
# Out:
#         cities
# 0  Albuquerque
# 1        Miami
# 2      Houston
# 3      Chicago
# 4     Santa Fe

# %% [markdown]
# ## Problem 6

# %% [markdown]
# Make a bar plot with `Cities` on the x axis and `Total_Times` on the y axis.

# %%
cities_df.plot.bar(x='cities', y=['Total_Times'], figsize=(8, 5))
plt.title('Trips')
plt.ylabel('Total')
plt.xticks(rotation=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2908/2773645787.py in <cell line: 0>()
#       1 cities_df.plot.bar(x='cities', y=['Total_Times'], figsize=(8, 5))
# ----> 2 plt.title('Trips')
#       3 plt.ylabel('Total')
#       4 plt.xticks(rotation=0)
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Problem 7

# %% [markdown]
# Drop the 'Total_Times' column from your data frame.

# %%
new_cities_df = cities_df.drop("Total_Times", axis=1)
new_cities_df
# Out:
#         cities      states   region  Times_1  Times_2  Times_3
# 0  Albuquerque  New Mexico  Midwest       10        2       12
# 1        Miami     Florida       SW        0        8       18
# 2      Houston       Texas  Midwest        5        0        4
# 3      Chicago    Illinois       NW        3       25        1
# 4     Santa Fe  New Mexico  Midwest       11       15       17

# %% [markdown]
# ## Problem 8

# %% [markdown]
# Restructure your data frame using the pandas `.melt()` method. In the `.melt()` method, specify `id_vars = ['Cities', 'States', 'Region']`. Save the melted data frame as a new variable called `cities_df_melted`. Print out `cities_df_melted`.
#
# > Note: make sure to read through the documentation for the `.melt()` method to understand what the method does.

# %%
pd.melt?

# %%
cities_df_melted = pd.melt(cities_df, id_vars = ["cities", "states", "region"])
cities_df_melted
# Out:
#          cities      states   region     variable  value
# 0   Albuquerque  New Mexico  Midwest      Times_1     10
# 1         Miami     Florida       SW      Times_1      0
# 2       Houston       Texas  Midwest      Times_1      5
# 3       Chicago    Illinois       NW      Times_1      3
# 4      Santa Fe  New Mexico  Midwest      Times_1     11
# 5   Albuquerque  New Mexico  Midwest      Times_2      2
# 6         Miami     Florida       SW      Times_2      8
# 7       Houston       Texas  Midwest      Times_2      0
# 8       Chicago    Illinois       NW      Times_2     25
# 9      Santa Fe  New Mexico  Midwest      Times_2     15
# 10  Albuquerque  New Mexico  Midwest      Times_3     12
# 11        Miami     Florida       SW      Times_3     18
# 12      Houston       Texas  Midwest      Times_3      4
# 13      Chicago    Illinois       NW      Times_3      1
# 14     Santa Fe  New Mexico  Midwest      Times_3     17
# 15  Albuquerque  New Mexico  Midwest  Total_Times     24
# 16        Miami     Florida       SW  Total_Times     26
# 17      Houston       Texas  Midwest  Total_Times      9
# 18      Chicago    Illinois       NW  Total_Times     29
# 19     Santa Fe  New Mexico  Midwest  Total_Times     43

# %% [markdown]
# ## Problem 9

# %% [markdown]
# Use the seaborn `barplot()` function to create a barplot of `cities_df_melted` with `Cities` on the x axis, `value` on the y axis and the hue parameter set to `variable`.

# %%
import seaborn as sns

# %%
sns.barplot()(x=["cities","cities_df_melted"] y=["value"], hue=("variable"))
# Out:
#   File "/tmp/ipykernel_2908/1764157040.py", line 1
#     sns.barplot()(x=["cities","cities_df_melted"] y=["value"], hue=("variable"))
#                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
