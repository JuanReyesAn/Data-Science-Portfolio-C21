# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanReyesAn/Data-Science-Portfolio-C21/blob/main/Copy_of_1d_Intro_to_Python%2CLists_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Exercises - Intro to Python & Lists

# %% [markdown]
# ## Working with lists

# %% [markdown]
# 1. Use a variable to represent a famous person’s name and then print that person’s name in lowercase, uppercase and title case.

# %%
King_of_pop = "Michael Jackson"
King_of_pop.lower()
# Out:
# 'michael jackson'

# %%
King_of_pop.upper()
# Out:
# 'MICHAEL JACKSON'

# %%
King_of_pop.capitalize()
# Out:
# 'Michael jackson'

# %% [markdown]
# 2. Print a message about the person you defined above using an f-string.

# %%
King_of_pop = "Michael Jackson"
message = f"and this years king of pop is {king_of_pop}"
print(message)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2871/1115364603.py in <cell line: 0>()
#       1 King_of_pop = "Michael Jackson"
# ----> 2 message = f"and this years king of pop is {king_of_pop}"
#       3 print(message)
#
# NameError: name 'king_of_pop' is not defined

# %% [markdown]
# 3. Store the names of at least 5 of your favorite movies in a list called `movies`.

# %%
movies = ["the last samurai", "Lord of the rings", "Spiderman", "Interstellar", "Spirit"]

# %% [markdown]
# 4. Remove one of the movies from your `movies` list.

# %%
del(movies[2])
print(movies)
# Out:
# ['the last samurai', 'Lord of the rings', 'Interstellar', 'Spirit']

# %% [markdown]
# 5. Sort your `movies` list in reverse alphabetical order.

# %%
movies[::-1]
# Out:
# ['Spirit', 'Interstellar', 'Lord of the rings', 'the last samurai']

# %% [markdown]
# 6. Use a slice to access the first 3 of your favorite movies.

# %%
movies[0:3]
# Out:
# ['the last samurai', 'Lord of the rings', 'Interstellar']

# %% [markdown]
# 7. Add your least favorite movie to your `movies` list.

# %%
movies.insert(0,"spiderman")
print(movies)
# Out:
# ['spiderman', 'spiderman', 'the last samurai', 'Lord of the rings', 'Interstellar', 'Spirit']

# %% [markdown]
# 8. Convert the float `16.4` to an integer.

# %%
convert = int(16.4)
print(convert)
# Out:
# 16

# %% [markdown]
# ## Challenge (only if you have time)

# %% [markdown]
# 1. Create a variable called `birthday` and set it equal to the string `'Happy Birthday to You!'`. Use slicing to access every other character in the variable `birthday`.
#
# Hints:
# - w3schools [slicing strings]( https://www.w3schools.com/python/python_strings_slicing.asp )
# - "Automate the Boring Stuff" [slicing strings]( https://automatetheboringstuff.com/3e/chapter8.html#:~:text=valid%20Python%20code.-,Indexes%20and%20Slices,-Strings%20use%20indexes )

# %%
birthday = "HappyBirthday to you"
birthday[0:5]
# Out:
# 'Happy'

# %%
birthday[5:13]
# Out:
# 'Birthday'

# %%
birthday[14:16]
# Out:
# 'to'

# %%
birthday[17:20]
# Out:
# 'you'

# %% [markdown]
# 2. Create a variable called `nested` and set it equal to the following nested list: `[[1,2,3], ['a','b','c']]`. Use indexing to access the `b` from your nested list. Use indexing to access `[2,3]` from your nested list.
